# %% [markdown]
# # This would be the steps to follow if you want to get rid of all the not so relevant info in the dataset and re formating some columns

# %%
import pandas as pd
df_sucio = pd.read_json('contratacionesabiertas_bulk.json')

# %% [markdown]
# ## Extracting _id from json filled column

# %%
finalisation_date = df_sucio["id"].apply(lambda x: x.split("-")[2:])
finalisation_date = finalisation_date.apply(lambda x: "-".join(x))

# %% [markdown]
# ## Reforminating date column and separating values so the access to the information is easier

# %%
years = df_sucio['date'].apply(lambda x: x.year)
months = df_sucio['date'].apply(lambda x: x.month)
days =  df_sucio['date'].apply(lambda x: x.day)

# %%
df_sucio["expeditionDay"] = days
df_sucio["expeditionMonth"] = months
df_sucio["expeditionYear"] = years

# %%
trimester = np.where(df_sucio["expeditionMonth"].values <= 3,1,
                     np.where((df_sucio["expeditionMonth"].values > 3) & (df_sucio["expeditionMonth"].values <= 6),2,
                             np.where((df_sucio["expeditionMonth"].values > 6) & (df_sucio["expeditionMonth"].values <= 9),3,4)))

# %%
df_sucio["expeditionTrimester"] = trimester

# %% [markdown]
# ## Extracting all relecant info from the buyer column

# %%
buyer = df_sucio['buyer'].apply(lambda x: re.sub("'",'"',x))
buyer = buyer.apply(lambda x: x.split('"'))

# %%
for i in buyer.index:
    if len(buyer[i]) > 9:
        buyer[i].pop(4)

# %%
for i in buyer.index:
    if len(buyer[i]) > 9:
        buyer[i].pop(4)

# %%
buyer = buyer.apply(lambda x: '"'.join(x))
for i in buyer.index:
    buyer[i] = json.loads(buyer[i])

# %%
aver = []
for i in buyer.index:
    if type(buyer[i]) != dict:
        aver.append(i)
aver

# %% [markdown]
# ## Now that we have all relevant info extrcated we can drop columns with irrelevant data for our data base

# %%
df_sucio['buyer'] = buyer
buyer_name = df_sucio['buyer'].apply(lambda x: x['name'])
buyer_id = df_sucio['buyer'].apply(lambda x: x['id'])
df_sucio['buyerName'] = buyer_name
df_sucio['buyerId'] = buyer_id
df_sucio = df_sucio.drop(columns=["buyer",'contracts','awards','tender','parties','tag','initiationType','language'])

# %% [markdown]
# # Dropping nan values

# %%
df_sucio = df_sucio.dropna()

# %% [markdown]
# ## Note: If you want to know why we are doing all of this see our exploration of this data on the "Data exploration and creation of a new dataset" notebook

# %% [markdown]
# ## For now we'll move into creating categories for our data this categories will go under the column with the name tag

# %%
import pandas as pd

# %%
df = pd.read_csv("mainDF.csv")

# %%
df['tag'] = 1

# %%
df
# Out:
#                              _id  cycle                 ocid       id  \
# 0       5e2a3797575b631d3c62539e   2016  ocds-07smqs-1003123  1003123
# 1       5e2a3798325093834fd90805   2016  ocds-07smqs-1003803  1003803
# 2       5e2a379837be1c3fcb93dd99   2016  ocds-07smqs-1009245  1009245
# 3       5e2a3798d0ac91b80a73a1af   2016  ocds-07smqs-1012355  1012355
# 4       5e2a3798cb04247fb1dcbd1b   2016  ocds-07smqs-1017118  1017118
# ...                          ...    ...                  ...      ...
# 283522  5e2a5afa0007ea3cf4b11ac5   2018  ocds-07smqs-1810512  1810512
# 283523  5e2a5afba6b0523b077b9df3   2018  ocds-07smqs-1811236  1811236
# 283524  5e2a5afb5ef1e767b740c298   2018  ocds-07smqs-1811256  1811256
# 283525  5e2a5afccfa55c38852577c0   2018  ocds-07smqs-1814739  1814739
# 283526  5e2a5afc8ec00de2a67a70e5   2018  ocds-07smqs-1816765  1816765
#
#                              date  expeditionDay  expeditionMonth  \
# ...

# %% [markdown]
# # We'll get every entity that we are interested on

# %%
df['buyerName'].unique()
# Out:
# array(['Procuraduría General de la República',
#        'Servicio de Administración Tributaria',
#        'Secretaría del Trabajo y Previsión Social',
#        'Comisión Nacional para el Uso Eficiente de la Energía',
#        'Instituto Nacional de Antropología e Historia',
#        'Instituto de Administración y Avalúos de Bienes Nacionales',
#        'Secretaría de Comunicaciones y Transportes',
#        'Agencia de Servicios a la Comercialización y Desarrollo de Mercados Agropecuarios',
#        'Secretaría de Agricultura, Ganadería, Desarrollo Rural, Pesca y Alimentación',
#        'Instituto Nacional de Desarrollo Social',
#        'Comisión Nacional del Agua', 'XE-IPN Canal 11',
#        'Secretaría de la Defensa Nacional',
#        'Servicio Nacional de Sanidad, Inocuidad y Calidad Agroalimentaria',
#        'Comisión Reguladora de Energía', 'Registro Agrario Nacional',
#        'Comisión Nacional de Arbitraje Médico',
# ...

# %% [markdown]
# # Now let's separate each individual entity into a category

# %% [markdown]
# ###  Note: This categories we're made to try and give people that will use our app a better framework to understand what they will get from the serch engine

# %%
seguridad = [
        "Secretaría de la Defensa Nacional",
        "Secretaría de Marina",
        "Comisión Nacional de Seguridad Nuclear y Salvaguardias",
        "Secretariado Ejecutivo del Sistema Nacional de Seguridad Pública",
        "Instituto de Seguridad Social para las Fuerzas Armadas Mexicana",
        "Policía Federal", 
        "Servicio de Protección Federal",
        "Instituto de Seguridad Social para las Fuerzas Armadas Mexicanas"
    ]

# %%
salud = [
        "Servicio Nacional de Sanidad, Inocuidad y Calidad Agroalimentaria",
        "Comisión Nacional de Arbitraje Médico",
        "Secretaría de Salud",
        "Comisión Nacional de Protección Social en Salud",
        "Centro Nacional para la Prevención y el Control del VIH/SIDA",
        "Centro Nacional de Equidad de Género y Salud Reproductiva",
        "Centro Nacional de Programas Preventivos y Control de Enfermedades",
        "Centro Nacional de la Transfusión Sanguínea",
        "Comisión Federal para la Protección contra Riesgos Sanitarios",
        "Servicios de Atención Psiquiátrica",
        "Comisión Nacional contra las Adicciones",
        "Hospital Infantil de México Federico Gómez",
        "Instituto Nacional de Neurología y Neurocirugía Manuel Velasco Suárez",
        "Hospital General de México ",
        "Instituto Nacional de Ciencias Médicas y Nutrición Salvador Zubirán",
        "Hospital General ",
        "Hospital Regional de Alta Especialidad de Ixtapaluca",
        "Instituto Nacional de Enfermedades Respiratorias Ismael Cosío Villegas",
        "Instituto Nacional de Perinatología Isidro Espinosa de los Reyes",
        "Instituto Nacional de Salud Pública",
        "Hospital Regional de Alta Especialidad de la Península de Yucatán",
        "Instituto Nacional de Rehabilitación Luis Guillermo Ibarra Ibarra",
        "Instituto Nacional de Pediatría",
        "Hospital Regional de Alta Especialidad de Ciudad Victoria ",
        "Hospital Regional de Alta Especialidad del Bajío",
        "Hospital Regional de Alta Especialidad de Oaxaca",
        "Laboratorios de Biológicos y Reactivos de México, S.A. de C.V.",
        "El Colegio de la Frontera Norte, A.C.",
        "Instituto Mexicano del Seguro Social",
        "Centro Regional de Alta Especialidad de Chiapas",
        "Instituto Nacional de Cancerología",
        "Instituto Nacional de Medicina Genómica",
        "Instituto Nacional de Cardiología Ignacio Chávez",
        "Instituto Nacional de Geriatría",
        "Instituto Nacional de Psiquiatría Ramón de la Fuente Muñiz",
        "Hospital Juárez de México"
    ]

# %%
energia = [
        "Comisión Nacional para el Uso Eficiente de la Energía",
        "Comisión Reguladora de Energía",
        "Secretaría de Energía",
        "Instituto Nacional de Electricidad y Energías Limpias",
        "Centro Nacional de Control de Energía",
        "Comisión Federal de Electricidad",
        "Instituto Mexicano de Tecnología del Agua",
        "Compañía Mexicana de Exploraciones, S.A. de C.V."
    ]

# %%
economia = [
        "Servicio de Administración Tributaria",
        "Instituto de Administración y Avalúos de Bienes Nacionales",
        "Agencia de Servicios a la Comercialización y Desarrollo de Mercados Agropecuarios",
        "Secretaría de Hacienda y Crédito Público",
        "Secretaría de Economía",
        "Comisión Nacional del Sistema de Ahorro para el Retiro",
        "Comité Nacional Mixto de Protección al Salario",
        "Comisión Nacional Bancaria y de Valores",
        "Instituto Nacional de la Economía Social",
        "Comisión Nacional de Seguros y Fianzas",
        "Administración del Patrimonio de la Beneficencia Pública",
        "Fideicomiso Fondo Nacional de Habitaciones Populares",
        "Fideicomiso de los Sistemas Normalizado de Competencia Laboral y de Certificación de Competencia Laboral",
        "Sociedad Hipotecaria Federal, S.N.C.",
        "Comisión Federal de Competencia Económica",
        "Comisión Nacional para la Protección y Defensa de los Usuarios de Servicios Financieros",
        "Banco Nacional de Comercio Exterior, S.N.C.",
        "Banco Nacional de Obras y Servicios Públicos, S.N.C.",
        "Nacional Financiera, S.N.C.",
        "ProMéxico",
        "Procuraduría de la Defensa del Contribuyente",
        "Colegio Nacional de Educación Profesional Técnica",
        "Instituto Mexicano del Petróleo",
        "Banco Nacional del Ejército, Fuerza Aérea y Armada, S.N.C.",
        "Financiera Nacional de Desarrollo Agropecuario, Rural, Forestal y Pesquero",
        "Fideicomiso del Fondo de Microfinanciamiento a Mujeres Rurales",
        "Fideicomiso de Riesgo Compartido",
        "Casa de Moneda de México",
        "Fideicomiso Fondo Nacional de Fomento Ejidal",
        "Instituto para la Protección al Ahorro Bancario",
        "Servicio de Administración y Enajenación de Bienes",
        "Comisión Nacional de los Salarios Mínimos",
        "Seguros de Crédito a la Vivienda SHF, S.A. de C.V.",
        "Fondo de Cultura Económica",
        "Autoridad Federal para el Desarrollo de las Zonas Económicas Especiales",
        "Banco del Ahorro Nacional y Servicios Financieros, S.N.C."
    ]

# %%
gobernacion = [
        "Procuraduría General de la República",
        "Presidencia de la República",
        "Secretaría de la Función Pública",
        "Secretaría de Gobernación",
        "Consejería Jurídica del Ejecutivo Federal",
        "Comisión Nacional de Mejora Regulatoria",
        "Archivo General de la Nación",
        "Tribunal Federal de Justicia Administrativa", 
        "Comisión Nacional de las Zonas Áridas",
        "Instituto Mexicano de la Propiedad Industrial",
        "Secretaría Ejecutiva del Sistema Nacional Anticorrupción",
        "Lotería Nacional para la Asistencia Pública"
    ]

# %%
medio_ambiente = [
        "Comisión Nacional del Agua",
        "Procuraduría Federal de Protección al Ambiente",
        "Secretaría de Medio Ambiente y Recursos Naturales",
        "Comisión Nacional de Áreas Naturales Protegidas",
        "Comisión Nacional de Hidrocarburos",
        "Comisión Nacional de Bioética",
        "Comisión Nacional Forestal",
        "Instituto Nacional de Ecología y Cambio Climático",
        "Agencia Nacional de Seguridad Industrial y de Protección al Medio Ambiente del Sector Hidrocarburos ",
        "Centro Nacional de Control del Gas Natural",
        "Comité Nacional para el Desarrollo Sustentable de la Caña de Azúcar",
        "Instituto Nacional del Suelo Sustentable",
        "Instituto de Ecología, A.C."

    ]

# %%
educacion = [
        "Secretaría de Educación Pública",
        "Colegio Superior Agropecuario del Estado de Guerrero",
        "Autoridad Educativa Federal en la Ciudad de México",
        "Universidad Pedagógica Nacional",
        "Coordinación General @prende.mx",
        "Instituto Politécnico Nacional",
        "Centro Nacional de Excelencia Tecnológica en Salud",
        "Tecnológico Nacional de México",
        "Instituto Nacional para la Educación de los Adultos",
        "Consejo Nacional de Fomento Educativo",
        "CIATEC, A.C. ",
        "El Colegio de la Frontera Sur",
        "Centro de Investigaciones y Estudios Superiores en Antropología Social",
        "Comisión de Operación y Fomento de Actividades Académicas del Instituto Politécnico Nacional",
        "Colegio de Postgraduados",
        "Instituto Nacional de la Infraestructura Física Educativa",
        "Centro de Enseñanza Técnica Industrial",
        "El Colegio de Michoacán, A.C.",
        "Centro de Investigación Científica y de Educación Superior de Ensenada, Baja California",
        "Productora Nacional de Biológicos Veterinarios",
        "Instituto Nacional para la Evaluación de la Educación",
        "El Colegio de San Luis, A.C.",
        "Colegio de Bachilleres",
        "Comisión Nacional de Libros de Texto Gratuitos"
    ]

# %%
comunicacion_transporte = [
        "Secretaría de Comunicaciones y Transportes",
        "Instituto Mexicano del Transporte",
        "Servicios a la Navegación en el Espacio Aéreo Mexicano",
        "Agencia Reguladora del Transporte Ferroviario",
        "Caminos y Puentes Federales de Ingresos y Servicios Conexos",
        "Aeropuertos y Servicios Auxiliares",
        "Administración Portuaria Integral de Mazatlán, S.A. de C.V.",
        "Aeropuerto Internacional de la Ciudad de México, S.A. de C.V.",
        "Servicios Aeroportuarios de la Ciudad de México, S.A. de C.V.",
        "Ferrocarril del Istmo de Tehuantepec, S.A. de C.V.",
        "Instituto Federal de Telecomunicaciones",
        "Televisión Metropolitana S.A. de C.V.",
        "Administración Portuaria Integral de Topolobampo, S.A. de C.V.",
        "Administración Portuaria Integral de Salina Cruz, S.A. de C.V.",
        "Telecomunicaciones de México",
        "Administración Portuaria Integral de Progreso, S.A. de C.V.",
        "Sistema Público de Radiodifusión del Estado Mexicano",
        "Administración Portuaria Integral de Dos Bocas, S.A. de C.V.",
        "Administración Portuaria Integral de Veracruz, S.A. de C.V.",
        "Administración Portuaria Integral de Coatzacoalcos, S.A. de C.V.",
        "Administración Portuaria Integral de Manzanillo, S.A. de C.V.",
        "Administración Portuaria Integral de Lázaro Cárdenas, S.A. de C.V.",
        "Administración Portuaria Integral de Guaymas, S.A. de C.V.",
        "Instituto Mexicano de la Radio",
        "Organismo Promotor de Inversiones en Telecomunicaciones",
        "Administración Portuaria Integral de Ensenada, S.A. de C.V.",
        "FONATUR Operadora Portuaria, S.A. de C.V.",
        "Administración Portuaria Integral de Tampico, S.A. de C.V.",
        "Administración Portuaria Integral de Puerto Madero, S.A. de C.V.",
        "Administración Portuaria Integral de Puerto Vallarta, S.A. de C.V.",
        "Administración Portuaria Integral de Altamira, S.A. de C.V.",
        "Administración Portuaria Integral de Tuxpan, S.A. de C.V.",
        "Estudios Churubusco Azteca, S.A.",
        "Instituto Mexicano de Cinematografía",
        "Centro de Capacitación Cinematográfica, A.C.",
        "Fideicomiso para la Cineteca Nacional"

    ]

# %%
social = [
        "Instituto Nacional de Desarrollo Social",
        "XE-IPN Canal 11",
        "Secretaría de Turismo",
        "Secretaría de Desarrollo Social",
        "Instituto Nacional de Migración",
        "Secretaría de Relaciones Exteriores",
        "Instituto Nacional de Bellas Artes y Literatura",
        "Coordinación Nacional de PROSPERA Programa de Inclusión Social",
        "Prevención y Readaptación Social",
        "Secretaría de Cultura",
        "Centros de Integración Juvenil, A.C.",
        "Pronósticos para la Asistencia Pública",
        "Instituto Nacional de Ciencias Penales",
        "Instituto Federal de Acceso a la Información y Protección de Datos",
        "Comisión Nacional para el Desarrollo de los Pueblos Indígenas",
        "Instituto Nacional de Lenguas Indígenas",
        "Diconsa, S.A. de C.V.",
        "Consejo de Promoción Turística de México, S.A. de C.V.",
        "Consejo Nacional de Evaluación de la Política de Desarrollo Social",
        "Instituto Nacional de las Mujeres",
        "Comisión Nacional de Vivienda",
        "Sistema Nacional para el Desarrollo Integral de la Familia",
        "Instituto Nacional de las Personas Adultas Mayores",
        "Instituto Mexicano de la Juventud",
        "Consejo Nacional para el Desarrollo y la Inclusión de las Personas con Discapacidad",
        "Comisión Nacional de Cultura Física y Deporte",
        "Servicio Postal Mexicano",
        "FONATUR Mantenimiento Turístico, S.A. de C.V.",
        "Educal, S.A. de C.V.",
        "Fondo Nacional de Fomento al Turismo",
        "Fondo Nacional para el Fomento de las Artesanías",
        "Compañía Operadora del Centro Cultural y Turístico de Tijuana, S.A. de C.V.",
        "Procuraduría Federal del Consumidor",
        "Talleres Gráficos de México",
        "Consejo Nacional para Prevenir la Discriminación"
    ]

# %%
investigacion = [
        "Instituto Nacional de Antropología e Historia",
        "Servicio de Información Agroalimentaria y Pesquera",
        "Centro de Investigación y Seguridad Nacional",
        "Notimex, Agencia de Noticias del Estado Mexicano",
        "Servicio Geológico Mexicano",
        "Centro de Investigación en Química Aplicada",
        "Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional",
        "Centro de Investigación y Docencia Económicas, A.C.",
        "Centro de Investigaciones Biológicas del Noroeste, S.C.",
        "Instituto Nacional de Enfermedades Respiratorias Ismael Cosío Villegas",
        "Comisión Ejecutiva de Atención a Víctimas",
        "Instituto Nacional de Investigaciones Forestales, Agrícolas y Pecuarias",
        "Centro de Investigación y Asistencia en Tecnología y Diseño del Estado de Jalisco, A.C.",
        "Centro de Investigación en Matemáticas, A.C.",
        "Centro de Investigación en Alimentación y Desarrollo, A.C.",
        "Consejo Nacional de Ciencia y Tecnología",
        "Instituto de Investigaciones ",
        "Instituto Nacional de Investigaciones Nucleares",
        "INFOTEC Centro de Investigación e Innovación en Tecnologías de la Información y Comunicación",
        "Instituto Nacional de Estadística Y Geografía",
        "Agencia Espacial Mexicana",
        "Instituto Nacional de Astrofísica, Óptica y Electrónica",
        "Centro de Investigaciones en Óptica, A.C.",
        "Instituto Nacional de Pesca y Acuacultura",
        "Centro de Investigación Científica de Yucatán, A.C.",
        "CIATEQ, A.C. Centro de Tecnología Avanzada",
        "Centro de Investigación y Desarrollo Tecnológico en Electroquímica, S.C.",
        "Centro de Investigación en Materiales Avanzados, S.C.",
        "Centro Nacional de Metrología",
        "Centro de Ingeniería y Desarrollo Industrial",
        "Centro de Investigación en Ciencias de Información Geoespacial, A.C.",
        "Corporación Mexicana de Investigación en Materiales, S.A. de C.V.",
        "Instituto Potosino de Investigación Científica y Tecnológica, A.C."

    ]

# %%
trabajo = [
        "Secretaría del Trabajo y Previsión Social",
        "Secretaría de Agricultura, Ganadería, Desarrollo Rural, Pesca y Alimentación",
        "Registro Agrario Nacional",
        "Comisión Nacional de Acuacultura y Pesca",
        "Servicio Nacional de Inspección y Certificación de Semillas",
        "Secretaría de Desarrollo Agrario, Territorial y Urbano",
        "Procuraduría Federal de la Defensa del Trabajo",
        "Instituto Nacional del Emprendedor",
        "Liconsa, S.A. de C.V.",
        "Patronato de Obras e Instalaciones del Instituto Politécnico Nacional",
        "Fideicomiso de Fomento Minero",
        "Exportadora de Sal, S.A. de C.V.",
        "Procuraduría Agraria",
        "Agroasemex, S.A.",
        "Instituto del Fondo Nacional para el Consumo de los Trabajadores",
        "Fondo de Garantía y Fomento para la Agricultura, Ganadería y Avicultura",
        "Tribunales Agrarios",
        "FONATUR Constructora, S.A. de C.V.",
        "Instituto Nacional para el Desarrollo de Capacidades del Sector Rural, A.C.",
        "Impresora y Encuadernadora Progreso, S.A. de C.V.",
        "Instituto de Seguridad y Servicios Sociales de los Trabajadores del Estado",
        "Fondo de Capitalización e Inversión del Sector Rural",
        "Fideicomiso de Formación y Capacitación para el Personal de la Marina Mercante Nacional"
    ]

# %% [markdown]
# # Addind the propper category to the tag column

# %%
for i in df.index:
    if df['buyerName'][i] in seguridad:
        df.loc[i,"tag"] = "seguridad"

# %%
for i in df.index:
    if df['buyerName'][i] in salud:
        df.loc[i,"tag"] = "salud"

# %%
for i in df.index:
    if df['buyerName'][i] in energia:
        df.loc[i,"tag"] = "energia"

# %%
for i in df.index:
    if df['buyerName'][i] in economia:
        df.loc[i,"tag"] = "economia"

# %%
for i in df.index:
    if df['buyerName'][i] in gobernacion:
        df.loc[i,"tag"] = "gobernacion"

# %%
for i in df.index:
    if df['buyerName'][i] in medio_ambiente:
        df.loc[i,"tag"] = "medio_ambiente"

# %%
for i in df.index:
    if df['buyerName'][i] in educacion:
        df.loc[i,"tag"] = "educacion"

# %%
for i in df.index:
    if df['buyerName'][i] in comunicacion_transporte:
        df.loc[i,"tag"] = "comunicacion_transporte"

# %%
for i in df.index:
    if df['buyerName'][i] in social:
        df.loc[i,"tag"] = "social"

# %%
for i in df.index:
    if df['buyerName'][i] in investigacion:
        df.loc[i,"tag"] = "investigacion"

# %%
for i in df.index:
    if df['buyerName'][i] in trabajo:
        df.loc[i,"tag"] = "trabajo"

# %%
df
# Out:
#                              _id  cycle                 ocid       id  \
# 0       5e2a3797575b631d3c62539e   2016  ocds-07smqs-1003123  1003123
# 1       5e2a3798325093834fd90805   2016  ocds-07smqs-1003803  1003803
# 2       5e2a379837be1c3fcb93dd99   2016  ocds-07smqs-1009245  1009245
# 3       5e2a3798d0ac91b80a73a1af   2016  ocds-07smqs-1012355  1012355
# 4       5e2a3798cb04247fb1dcbd1b   2016  ocds-07smqs-1017118  1017118
# ...                          ...    ...                  ...      ...
# 283522  5e2a5afa0007ea3cf4b11ac5   2018  ocds-07smqs-1810512  1810512
# 283523  5e2a5afba6b0523b077b9df3   2018  ocds-07smqs-1811236  1811236
# 283524  5e2a5afb5ef1e767b740c298   2018  ocds-07smqs-1811256  1811256
# 283525  5e2a5afccfa55c38852577c0   2018  ocds-07smqs-1814739  1814739
# 283526  5e2a5afc8ec00de2a67a70e5   2018  ocds-07smqs-1816765  1816765
#
#                              date  expeditionDay  expeditionMonth  \
# ...

# %%
df['tag'].unique()
# Out:
# array(['gobernacion', 'economia', 'trabajo', 'energia', 'investigacion',
#        'comunicacion_transporte', 'social', 'medio_ambiente', 'seguridad',
#        'salud', 'educacion'], dtype=object)

# %%
df.to_csv("Datasets/Main_df.csv")

# %% [markdown]
# # Now we have to separate the information into different smaller data frames according to the tag that each entry has

# %%
gobernacion_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'gobernacion':
        gobernacion_df = gobernacion_df.append(df.iloc[i])
gobernacion_df
# Out:
#         Unnamed: 0                       _id   buyerId  \
# 0              0.0  5e2a3797575b631d3c62539e   PGR-251
# 100          100.0  5e2a379b22fe70190b14eede    PR-244
# 101          101.0  5e2a379b7ca916441dc9b8e8    PR-244
# 130          130.0  5e2a379c1d8e3511d79c7200  SHCP-270
# 137          137.0  5e2a379c93ee349e5e2b5250    PR-244
# ...            ...                       ...       ...
# 224822    224822.0  5e2a533cf7ba085456305e2e    AGN-25
# 224825    224825.0  5e2a533c40950e1041c480e6    AGN-25
# 224830    224830.0  5e2a533c76383fbb51b62092    AGN-25
# 224938    224938.0  5e2a5341858e6ebc9a0d04de  TFJA-304
# 225010    225010.0  5e2a534459ab61734b95f46c  TFJA-304
#
#                                           buyerName   cycle  \
# 0              Procuraduría General de la República  2016.0
# 100                     Presidencia de la República  2016.0
# 101                     Presidencia de la República  2016.0
# ...

# %%
gobernacion_df.to_csv('Datasets/gobernacion_df.csv',sep="~")

# %%
economia_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'economia':
        economia_df = economia_df.append(df.iloc[i])
economia_df
# Out:
#         Unnamed: 0                       _id       buyerId  \
# 1              1.0  5e2a3798325093834fd90805       SAT-284
# 5              5.0  5e2a3798ccd1a3c28b5d561e  INDAABIN-173
# 6              6.0  5e2a379810fc9bce0138fcb2  INDAABIN-173
# 8              8.0  5e2a3798062f9471dec60004  INDAABIN-173
# 9              9.0  5e2a3798e15634080b1a95a0  INDAABIN-173
# ...            ...                       ...           ...
# 225105    225105.0  5e2a5347465b68efa58f42f6    CONALEP-71
# 225110    225110.0  5e2a5348f2004e15a400e868        CMM-32
# 225111    225111.0  5e2a5348f1d95687803c944d     NAFIN-233
# 225122    225122.0  5e2a53492e1ff0a571b774c6  BANCOMEXT-27
# 225131    225131.0  5e2a534bbb216a0dd34d4ae1       SAE-285
#
#                                                 buyerName   cycle  \
# 1                   Servicio de Administración Tributaria  2016.0
# 5       Instituto de Administración y Avalúos de Biene...  2016.0
# ...

# %%
economia_df.to_csv('Datasets/economia_df.csv',sep="~")

# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets/Main_df.csv")

# %%
trabajo_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'trabajo':
        trabajo_df = trabajo_df.append(df.iloc[i])

# %%
trabajo_df.to_csv('Datasets/trabajo_df.csv',sep="~")

# %%
energia_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'energia':
        energia_df = energia_df.append(df.iloc[i])

# %%
energia_df.to_csv('Datasets/energia_df.csv',sep="~")

# %%
investigacion_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'investigacion':
        investigacion_df = investigacion_df.append(df.iloc[i])
investigacion_df.to_csv('Datasets/investigacion_df.csv',sep="~")

# %%
comunicacion_transporte_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'comunicacion_transporte':
        comunicacion_transporte_df = comunicacion_transporte_df.append(df.iloc[i])
comunicacion_transporte_df.to_csv('Datasets/comunicacion_transporte_df.csv',sep="~")

# %%
social_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'social':
        social_df = social_df.append(df.iloc[i])
social_df.to_csv('Datasets/social_df.csv',sep="~")

# %%
seguridad_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'seguridad':
        seguridad_df = seguridad_df.append(df.iloc[i])
seguridad_df.to_csv('Datasets/seguridad_df.csv',sep="~")

# %%
salud_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'salud':
        salud_df = salud_df.append(df.iloc[i])
salud_df.to_csv('Datasets/salud_df.csv',sep="~")

# %%
educacion_df = pd.DataFrame()
for i in df.index:
    if df.iloc[i]['tag'] == 'educacion':
        educacion_df = educacion_df.append(df.iloc[i])
educacion_df.to_csv('Datasets/educacion_df.csv',sep="~")

# %%
parties = pd.read_csv("Datasets/parties.csv")

# %%
parties.to_csv("Datasets/parties.csv",sep="~")

# %% [markdown]
# # So I messed up and didnt add the index=False parameter, so it's time to fixed that up

# %%
import pandas as pd

# %%
comunicacion = pd.read_csv("Datasets/comunicacion_transporte_df.csv",sep="~")
economia = pd.read_csv("Datasets/economia_df.csv",sep="~")
educacion = pd.read_csv("Datasets/educacion_df.csv",sep="~")
energia = pd.read_csv("Datasets/energia_df.csv",sep="~")
gobernacion = pd.read_csv("Datasets/gobernacion_df.csv",sep="~")
investigacion = pd.read_csv("Datasets/investigacion_df.csv",sep="~")
Main = pd.read_csv("Datasets/Main_df.csv",sep=",")
ambiente = pd.read_csv("Datasets/medio_ambiente_df.csv",sep="~")
parties = pd.read_csv("Datasets/parties.csv",sep="~")
salud = pd.read_csv("Datasets/salud_df.csv",sep="~")
seguridad = pd.read_csv("Datasets/seguridad_df.csv",sep="~")
social = pd.read_csv("Datasets/social_df.csv",sep="~")
trabajo = pd.read_csv("Datasets/trabajo_df.csv",sep="~")

# %% [markdown]
# ## Off of my incompetency some new columns were created so im just getting rid of them

# %%
comunicacion = comunicacion.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
economia = economia.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
educacion = educacion.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
energia = energia.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
gobernacion = gobernacion.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
investigacion = investigacion.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
ambiente = ambiente.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
salud = salud.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
seguridad = seguridad.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
social = social.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
trabajo = trabajo.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
comunicacion = comunicacion.drop(columns=['id','ocid'])
economia = economia.drop(columns=['id','ocid'])
educacion = educacion.drop(columns=['id','ocid'])
energia = energia.drop(columns=['id','ocid'])
gobernacion = gobernacion.drop(columns=['id','ocid'])
investigacion = investigacion.drop(columns=['id','ocid'])
ambiente = ambiente.drop(columns=['id','ocid'])
salud = salud.drop(columns=['id','ocid'])
seguridad = seguridad.drop(columns=['id','ocid'])
social = social.drop(columns=['id','ocid'])
trabajo = trabajo.drop(columns=['id','ocid'])

# %%
Main = Main.drop(columns=['Unnamed: 0','id','ocid'])

# %%
parties = parties.drop(columns=['Unnamed: 0'])

# %%
comunicacion.to_csv("Datasetss/comunicacion_transporte_df.csv",sep="~",index=False)

# %% [markdown]
# # We are using "~" as a separator for our own purposes you don't need to add that parameter if you don't want to.

# %%
economia.to_csv("Datasetss/economia_df.csv",sep="~",index=False)
educacion.to_csv("Datasetss/educacion_df.csv",sep="~",index=False)
energia.to_csv("Datasetss/energia_df.csv",sep="~",index=False)
gobernacion.to_csv("Datasetss/gobernacion_df.csv",sep="~",index=False)
investigacion.to_csv("Datasetss/investigacion_df.csv",sep="~",index=False)
Main.to_csv("Datasetss/Main_df.csv",sep=",",index=False)
ambiente.to_csv("Datasetss/medio_ambiente_df.csv",sep="~",index=False)
parties.to_csv("Datasetss/parties.csv",sep="~",index=False)
salud.to_csv("Datasetss/salud_df.csv",sep="~",index=False)
seguridad.to_csv("Datasetss/seguridad_df.csv",sep="~",index=False)
social.to_csv("Datasetss/social_df.csv",sep="~",index=False)
trabajo.to_csv("Datasetss/trabajo_df.csv",sep="~",index=False)
